# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("StressLevelDataset.csv")

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
# ...

# %%
sns.violinplot(data=df, x="study_load", y="academic_performance")
# Out:
# <Axes: xlabel='study_load', ylabel='academic_performance'>

# %%
sns.violinplot(data=df, x="study_load", y="depression")
# Out:
# <Axes: xlabel='study_load', ylabel='depression'>

# %%
sns.violinplot(data=df, x="study_load", y="self_esteem")
# Out:
# <Axes: xlabel='study_load', ylabel='self_esteem'>

# %%
sns.violinplot(data=df, x="study_load", y="sleep_quality")
# Out:
# <Axes: xlabel='study_load', ylabel='sleep_quality'>

# %%
sns.violinplot(data=df, x="study_load", y="bullying")
# Out:
# <Axes: xlabel='study_load', ylabel='bullying'>

# %%
for column in df.columns:
    # Print min and max for each column
    print(f"{column}:")
    print(f"  Min: {df[column].min()}")
    print(f"  Max: {df[column].max()}")
    print()
# Out:
# anxiety_level:
#   Min: 0
#   Max: 21
#
# self_esteem:
#   Min: 0
#   Max: 30
#
# mental_health_history:
#   Min: 0
#   Max: 1
#
# depression:
#   Min: 0
#   Max: 27
#
# headache:
#   Min: 0
#   Max: 5
#
# blood_pressure:
#   Min: 1
#   Max: 3
#
# sleep_quality:
#   Min: 0
#   Max: 5
#
# breathing_problem:
#   Min: 0
#   Max: 5
#
# noise_level:
#   Min: 0
#   Max: 5
#
# living_conditions:
#   Min: 0
#   Max: 5
#
# safety:
#   Min: 0
#   Max: 5
#
# basic_needs:
#   Min: 0
#   Max: 5
#
# academic_performance:
#   Min: 0
#   Max: 5
#
# study_load:
#   Min: 0
#   Max: 5
#
# teacher_student_relationship:
#   Min: 0
#   Max: 5
#
# future_career_concerns:
#   Min: 0
#   Max: 5
#
# social_support:
#   Min: 0
#   Max: 3
#
# peer_pressure:
#   Min: 0
#   Max: 5
#
# extracurricular_activities:
#   Min: 0
#   Max: 5
#
# bullying:
#   Min: 0
#   Max: 5
#
# stress_level:
#   Min: 0
#   Max: 2

# %%
grouped_data = df.groupby('study_load')['academic_performance'].mean()

# Print the average academic performance for each study load
for study_load, avg_academic_performance in grouped_data.items():
    print(f'Study Load {study_load}: Average Academic Performance {avg_academic_performance:.2f}')
# Out:
# Study Load 0: Average Academic Performance 2.46
# Study Load 1: Average Academic Performance 4.18
# Study Load 2: Average Academic Performance 3.35
# Study Load 3: Average Academic Performance 2.15
# Study Load 4: Average Academic Performance 1.74
# Study Load 5: Average Academic Performance 1.83

# %%
# Filter rows where study_load is 5
filtered_df = df[df['study_load'] == 5]

# Calculate the average academic_performance for those rows
average_academic_performance = filtered_df['academic_performance'].mean()

# Print the result
print(f"The average academic performance for those who rated a study load of 5 is: {average_academic_performance}")
# Out:
# The average academic performance for those who rated a study load of 5 is: 1.828125

# %%
grouped_data_esteem = df.groupby('study_load')['self_esteem'].mean()

# Print the average academic performance for each study load
for study_load, avg_self_esteem in grouped_data_esteem.items():
    print(f'Study Load {study_load}: Average Self Esteem {avg_self_esteem:.2f}')
# Out:
# Study Load 0: Average Self Esteem 17.35
# Study Load 1: Average Self Esteem 24.88
# Study Load 2: Average Self Esteem 22.50
# Study Load 3: Average Self Esteem 15.55
# Study Load 4: Average Self Esteem 9.10
# Study Load 5: Average Self Esteem 9.76

# %%
grouped_data_depression = df.groupby('study_load')['depression'].mean()

# Print the average academic performance for each study load
for study_load, avg_depression in grouped_data_depression.items():
    print(f'Study Load {study_load}: Average Depression Level {avg_depression:.2f}')
# Out:
# Study Load 0: Average Depression Level 12.70
# Study Load 1: Average Depression Level 5.51
# Study Load 2: Average Depression Level 8.35
# Study Load 3: Average Depression Level 15.67
# Study Load 4: Average Depression Level 19.19
# Study Load 5: Average Depression Level 19.59

# %%
grouped_data_anxiety = df.groupby('study_load')['anxiety_level'].mean()

# Print the average academic performance for each study load
for study_load, avg_anxiety in grouped_data_anxiety.items():
    print(f'Study Load {study_load}: Average Anxiety Level {avg_anxiety:.2f}')
# Out:
# Study Load 0: Average Anxiety Level 10.30
# Study Load 1: Average Anxiety Level 4.94
# Study Load 2: Average Anxiety Level 8.27
# Study Load 3: Average Anxiety Level 13.89
# Study Load 4: Average Anxiety Level 16.15
# Study Load 5: Average Anxiety Level 15.67
